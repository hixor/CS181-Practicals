# %%
import pandas as pd

# %%
check1 = pd.read_csv('all_mols_1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ed9dbe1f44c6> in <module>()
# ----> 1 check1 = pd.read_csv('all_mols_1')
#
# ...

# %%
check1.shape
# Out:
# (54150, 2)

# %%
check1
# Out:
#        0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 0      0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 1      0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 2      0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 3      0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 4      0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 5      0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 6      0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 7      0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 8      0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 9      0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 10     0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 11     0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 12     0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 13     0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# 14     0  <rdkit.Chem.rdchem.Mol object at 0x12f15dad0>
# 15     0  <rdkit.Chem.rdchem.Mol object at 0x12f15da60>
# ...
